# %% [markdown]
# # Mine Safety
#
# We're interested in [US mine safety](https://arlweb.msha.gov/drs/drshome.htm), thank goodness we can search for these things.

# %% [markdown]
# ## Setup: Import what you'll need to search and scrape and Selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# ## Starting from `https://arlweb.msha.gov/drs/drshome.htm`, search for every operator with 'dirt' in their name, including abandoned mines.
#
# > - *Tip: If you can't make an element work using name, class or ID, try to use the XPath*

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://arlweb.msha.gov/drs/drshome.htm')

# %%
text_input = driver.find_element_by_name('OperSearch')

# %%
#Let's scroll down, just in case:
driver.execute_script("arguments[0].scrollIntoView(true)", text_input)

# %%
text_input.send_keys('dirt')

# %%
#Now we need to click (or unclick the exclude abandoned button):
include_abadoned_button = driver.find_element_by_name('Abandoned')
include_abadoned_button.click()

# %%
#And now to launch the search:
search_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table/tbody/tr[7]/td[3]/input[1]')
search_button.click()

# %% [markdown]
# ## Scrape the results page, saving it as `dirt-operators.csv`
#
# > - *Tip: Think about what each row in your dataset will be, and start by looping through that*
# > - *Tip: Printing is cool and good! Print everything! Move it into a dictionary later.*
# > - *Tip: If you don't want a row, think about what's in the row that makes it different. You can use an `if` statement or list slicing to skip the ones you aren't interested in.*
# > - *Tip: Make sure your dictionary and your loop variable have DIFFERENT NAMES*
# > - *Tip: After you've made your dictionary (and printed it, of course), you'll want to add it to your list of rows*
# > - *Tip: Be sure to import pandas to convert it to a dataframe*
# > - *Tip: Make sure you don't include the index when saving your dataframe*

# %% [markdown]
# ### Hopefully you know that each `tr` is supposed to be a row of your data. What is the index of the first row element that is actually a result?
#
# > - *Tip: `.text` will help you here.*
# > - *Tip: You aren't interesting in annotations or anything, just mines and where they are from*
# > - *Tip: Using `print("-----")` will help you keep track of different rows*
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third. You can use this to skip ahead to the 'good' data if you want*

# %%
dirt_mines = driver.find_elements_by_tag_name('tr')
rows = []
for mines in dirt_mines[7:-1]: #This slicing gets rid of stuff at the beginning we don't want, and the footnote with the total hits (132).
    print('--------')
    row = {}
    row_id = mines.find_element_by_tag_name('font')
    state = mines.find_element_by_tag_name('b')
    operator = mines.find_elements_by_tag_name('font')[2]
    name = mines.find_elements_by_tag_name('font')[3]
    mine_type = mines.find_elements_by_tag_name('font')[4]
    cm = mines.find_elements_by_tag_name('font')[5]
    status = mines.find_elements_by_tag_name('font')[6]
    commodity = mines.find_elements_by_tag_name('font')[7]
    url = mines.find_element_by_name('submit')
    print(row_id.text, state.text, operator.text, name.text, mine_type.text, cm.text, status.text, commodity.text, url.get_attribute('src'))
# Out:
# --------
# 3503598 OR Newberg Rock & Dirt   Newberg Rock & Dirt Surface M  Active  Crushed, Broken Stone NEC  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 0502030 CO Allied Dirt Moving Company   Allied Dirt Moving Co Pit & Plant Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4801789 ND AM Dirtworks & Aggregate Sales   AM Dirtworks & Aggregate Sales Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4201449 UT Atlas-Dirty Devil Mining   Unit Train Loading Facility Facility C  Abandoned  Coal (Bituminous)  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4201450 UT Atlas-Dirty Devil Mining   Blackie Surface Mine & Prep Plant Surface C  Abandoned  Coal (Bituminous)  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1002257 ID Babe's Dirt Work   Hitt Pit, Inc. Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1601167 LA Bar-Lin Dirt Company   Bar-Lin Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4103265 TX Barber'S Dirt Pit   Barber'S Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1401575 KS Bender Sand & Dirt   BENDER SAND & DIRT Surface M  Intermittent  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1700776 ME BERT'S DIRT   BERT'S DIRT Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1601251 LA Big D Dirt Service Inc   Dorothy V Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 0301963 AR Big Red Dirt Farm LLC   Big Red Dirt Farm Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1601082 LA Big River Dirt Pit   Big River Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 3401751 OK Bob Harris Dirt Contracting   Harris Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1600916 LA Bohannon Sand & Dirt   BOHANNON SAND & DIRT Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 3401211 OK Bratcher'S Sand & Dirt   Eubanks Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 0301267 AR Brewer Dirt Works   Brewer Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1600956 LA Buck'S Dirt Pit   Buck'S Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 2200033 MS C & G Dirt Hauling   Laurel Brick & Tile Surface M  Abandoned  Common Clays NEC  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 0504953 NM C N C Dirt Movers, Inc.   Foster Canyon Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 3401929 OK Cambridge Dirt Sand and Gravel LLC   Cambridge #1 Surface M  Abandoned  Sand, Industrial NEC  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1302445 IA Central Iowa Dirt & Demo LLC   Woolstock Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1601106 LA Crowes Trucking & Dirt Pit Services   Crowes Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 3400915 OK D & H Dirt   D & H Dirt Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1600983 LA Diez Dirt & Sand Hauling Inc   Amite Acres Dredge Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4503200 WA Dirt Cheap   Dirt Cheap Surface M  Abandoned  Common Clays NEC  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 3401266 OK Dirt Company   Pit #1 Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 3401468 OK Dirt Company   Hicks Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 5001797 AK Dirt Company   Bush Pilot Surface M  Intermittent  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4608254 WV Dirt Con   Hog Lick Quarry Surface M  Abandoned  Crushed, Broken Limestone NEC  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 
surface M  Intermittent  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4300776 VT SIMPSON DIRTWORX LLC   Chieftan 1400 Surface M  Intermittent  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 0103209 AL Slay'S Dirt Hauling   SLAY PIT Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1601159 LA Southside Dirt Company   Southside Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 2302283 MO Spry's Dirt & Gravel, Inc.   Mike's Money Pit Surface M  Intermittent  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4102586 TX Stewart Dirt Pit   Stewart Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4104475 TX Stewart Dirt Work, Inc.   Stewart Dirt Work Inc - Hanna Pit Surface M  Abandoned  Crushed, Broken Stone NEC  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 3800617 SC Sweat'S Dirt Hauling Inc   Highway 642 Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1601234 LA Toler Roe Dirt Pit   Toler Roe Dirt Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4104648 TX Tres Palacios Dirt, Sand & Gravel   La Calichera Pit Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 2103518 MN Vogt Dirt Service   Crusher Surface M  Intermittent  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 1601292 LA Watson Dirt Sand & Gravel Pit Inc   ADDISON LEASE Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4103429 TX Y B Dirt & Loam   Y B Mine Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg
# --------
# 4103264 TX Yarbrough Dirt Pit Inc   Yarbrough Dirt Pit #1 Surface M  Abandoned  Construction Sand and Gravel  https://arlweb.msha.gov/drs/images/moreinfo.jpg

# %% [markdown]
# ### Loop through each operator result, printing its name
#
# > - *Tip: If you have a list called `animals`, `animals[2:]` will skip the first two and start with the third.*
# > - *Tip: You can use list slicing or an `if` statement to skip the non-data row(s). List slicing is probably easier, even if you aren't comfortable with it.*
# > - *Tip: or honestly you can use `try` and `except` if you know how it works.*
# > - *Tip: Once you have the "right" rows of data, you're going to be looking for a certain tag inside*
# > - *Tip: Sometimes you can't say "give me this class," and instead you have to say "give me all of the `div` elements, and then give me the third one."*

# %%
#See above.

# %% [markdown]
# ### Loop through each operator result, printing its ID
#
# There should be ONE code per row, and NO empty rows between them.

# %%
#See above.

# %% [markdown]
# ## Saving the results
#
# ### Loop through each `tr` to create a list of dictionaries
#
# Each dictionary must contain
#
# - Operator ID
# - Operator name
# - Mine name
# - State
# - Mine type
# - Coal or metal
# - Status
# - Commodity
#
# Create a new dictionary for each row.
#
# > - *Tip: Start with an empty dictionary, then add the keys one at a time like we did during class*
# > - *Tip: You might want to save all of the cells in a variable, then use indexes to get the second, third, fourth, etc.*
# > - *Tip: I know you already skipped a bunch of rows already, but one of them still might be bad! Which one is it? How can you skip it? You might need to slice out some of the end of your list, too. Use `print` to help you debug, or just look at the page closely.*
# > - *Tip: Or, if you did the other homework already, `try` / `except` is also an option*

# %%
dirt_mines = driver.find_elements_by_tag_name('tr')
rows = []
for mines in dirt_mines[7:-1]: 
    row = {}
    row['Operator ID'] = mines.find_element_by_tag_name('font').text
    row['Operator'] = mines.find_elements_by_tag_name('font')[2].text
    row['Mine name'] = mines.find_elements_by_tag_name('font')[3].text
    row['State'] = mines.find_element_by_tag_name('b').text
    row['Mine type'] = mines.find_elements_by_tag_name('font')[4].text
    row['Coal or metal'] = mines.find_elements_by_tag_name('font')[5].text
    row['Status'] = mines.find_elements_by_tag_name('font')[6].text
    row['Commodity'] = mines.find_elements_by_tag_name('font')[7].text
    #row['url'] = mines.find_element_by_name('submit')
    rows.append(row)
    #print(row_id.text, state.text, operator.text, name.text, mine_type.text, cm.text, status.text, commodity.text, url.get_attribute('src'))
    
    
print(rows)
# Out:
# [{'Operator ID': '3503598', 'Operator': 'Newberg Rock & Dirt  ', 'Mine name': 'Newberg Rock & Dirt', 'State': 'OR', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Active ', 'Commodity': 'Crushed, Broken Stone NEC '}, {'Operator ID': '0502030', 'Operator': 'Allied Dirt Moving Company  ', 'Mine name': 'Allied Dirt Moving Co Pit & Plant', 'State': 'CO', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '4801789', 'Operator': 'AM Dirtworks & Aggregate Sales  ', 'Mine name': 'AM Dirtworks & Aggregate Sales', 'State': 'ND', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '4201449', 'Operator': 'Atlas-Dirty Devil Mining  ', 'Mine name': 'Unit Train Loading Facility', 'State': 'UT', 'Mine type': 'Facility', 'Coal or metal': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}, {'Operator ID': '4201450', 'Operator': 'Atlas-Dirty Devil Mining  ', 'Mine name': 'Blackie Surface Mine & Prep Plant', 'State': 'UT', 'Mine type': 'Surface', 'Coal or metal': 'C ', 'Status': 'Abandoned ', 'Commodity': 'Coal (Bituminous) '}, {'Operator ID': '1002257', 'Operator': "Babe's Dirt Work  ", 'Mine name': 'Hitt Pit, Inc.', 'State': 'ID', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1601167', 'Operator': 'Bar-Lin Dirt Company  ', 'Mine name': 'Bar-Lin Dirt Pit', 'State': 'LA', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '4103265', 'Operator': "Barber'S Dirt Pit  ", 'Mine name': "Barber'S Dirt Pit", 'State': 'TX', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1401575', 'Operator': 'Bender Sand & Dirt  ', 'Mine name': 'BENDER SAND & DIRT', 'State': 'KS', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Intermittent ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1700776', 'Operator': "BERT'S DIRT  ", 'Mine name': "BERT'S DIRT", 'State': 'ME', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1601251', 'Operator': 'Big D Dirt Service Inc  ', 'Mine name': 'Dorothy V Pit', 'State': 'LA', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '0301963', 'Operator': 'Big Red Dirt Farm LLC  ', 'Mine name': 'Big Red Dirt Farm', 'State': 'AR', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1601082', 'Operator': 'Big River Dirt Pit  ', 'Mine name': 'Big River Dirt Pit', 'State': 'LA', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '3401751', 'Operator': 'Bob Harris Dirt Contracting  ', 'Mine name': 'Harris Pit', 'State': 'OK', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1600916', 'Operator': 'Bohannon Sand & Dirt  ', 'Mine name': 'BOHANNON SAND & DIRT', 'State': 'LA', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '3401211', 'Operator': "Bratcher'S Sand & Dirt  ", 'Mine name': 'Eubanks Pit', 'State': 'OK', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '0301267', 'Operator': 'Brewer Dirt Works  ', 'Mine name': 'Brewer Pit', 'State': 'AR', 'Mine type': 'Surface', 'Coal or metal': 'M ', 'Status': 'Abandoned ', 'Commodity': 'Construction Sand and Gravel '}, {'Operator ID': '1600956', 'Operator':  ...

# %% [markdown]
# ### Save that to a CSV named `dirt-operators.csv`

# %%
len(rows)
# Out:
# 132

# %%
import pandas as pd

# %%
df = pd.DataFrame(rows)
df.head()
# Out:
#   Coal or metal                      Commodity  \
# 0            M      Crushed, Broken Stone NEC
# 1            M   Construction Sand and Gravel
# 2            M   Construction Sand and Gravel
# 3            C              Coal (Bituminous)
# 4            C              Coal (Bituminous)
#
#                            Mine name Mine type  \
# 0                Newberg Rock & Dirt   Surface
# 1  Allied Dirt Moving Co Pit & Plant   Surface
# 2     AM Dirtworks & Aggregate Sales   Surface
# 3        Unit Train Loading Facility  Facility
# 4  Blackie Surface Mine & Prep Plant   Surface
#
#                            Operator Operator ID State      Status
# 0             Newberg Rock & Dirt       3503598    OR     Active
# 1      Allied Dirt Moving Company       0502030    CO  Abandoned
# 2  AM Dirtworks & Aggregate Sales       4801789    ND  Abandoned
# 3        Atlas-Dirty Devil Mining       4201449    UT  Abandoned
# 4        Atlas-Dirty Devil Mining       4201450    UT  Abandoned

# %%
df.to_csv('dirt-operators.csv', index=False)

# %% [markdown]
# ### Open the CSV file and examine the first few.
#
# Make sure you didn't save that extra weird unnamed index column.

# %%
df2 = pd.read_csv('dirt-operators.csv')

# %%
df2.head()
# Out:
#   Coal or metal                      Commodity  \
# 0            M      Crushed, Broken Stone NEC
# 1            M   Construction Sand and Gravel
# 2            M   Construction Sand and Gravel
# 3            C              Coal (Bituminous)
# 4            C              Coal (Bituminous)
#
#                            Mine name Mine type  \
# 0                Newberg Rock & Dirt   Surface
# 1  Allied Dirt Moving Co Pit & Plant   Surface
# 2     AM Dirtworks & Aggregate Sales   Surface
# 3        Unit Train Loading Facility  Facility
# 4  Blackie Surface Mine & Prep Plant   Surface
#
#                            Operator  Operator ID State      Status
# 0             Newberg Rock & Dirt        3503598    OR     Active
# 1      Allied Dirt Moving Company         502030    CO  Abandoned
# 2  AM Dirtworks & Aggregate Sales        4801789    ND  Abandoned
# 3        Atlas-Dirty Devil Mining        4201449    UT  Abandoned
# 4        Atlas-Dirty Devil Mining        4201450    UT  Abandoned

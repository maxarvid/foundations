# %% [markdown]
# # Dark Sky API (Weather)
#
# Answer the following questions using the [Dark Sky API](https://darksky.net/dev/). I've added three cells for each question but you're free to use more or less! Hold `Shift` and hit `Enter` to run a cell, and use the `+` on the top left to add a new cell to a notebook.
#
# If you spend some time reading the documentation your life will probably be a little bit easier!
#
# ## 0) Import any libraries you might need
#
# - *Tip: We're going to be downloading things from the internet, so we probably need `requests`.*

# %%
import requests

# %%
#gonna save my secret key right here: 4a49a43f92c8ce2a327f67aa2f020d79

# %% [markdown]
# ## 1) Make a request from the Dark Sky API for where you were born (or lived, or want to visit!).
#
# - *Tip: The URL we used in class was for a place near San Francisco. What was the format of the endpoint that made this happen?*
# - *Tip: Save the URL as a separate variable, and be sure to not have `[` and `]` inside.*
# - *Tip: How is north vs. south and east vs. west latitude/longitude represented? Is it the normal North/South/East/West?*
# - *Tip: You know it's JSON, but Python doesn't! Make sure you aren't trying to deal with plain text.*
# - *Tip: Once you've imported the JSON into a variable, check the timezone's name to make sure it seems like it got the right part of the world!*

# %%
response = requests.get('https://api.darksky.net/forecast/4a49a43f92c8ce2a327f67aa2f020d79/59.334591,18.063240')

# %%
data = response.json()

# %%
data
# Out:
# {'latitude': 59.334591,
#  'longitude': 18.06324,
#  'timezone': 'Europe/Stockholm',
#  'currently': {'time': 1527794526,
#   'summary': 'Clear',
#   'icon': 'clear-day',
#   'precipIntensity': 0,
#   'precipProbability': 0,
#   'temperature': 57.39,
#   'apparentTemperature': 57.39,
#   'dewPoint': 36.23,
#   'humidity': 0.45,
#   'pressure': 1024.21,
#   'windSpeed': 7.66,
#   'windGust': 8.24,
#   'windBearing': 142,
#   'cloudCover': 0,
#   'uvIndex': 0,
#   'visibility': 6.22,
#   'ozone': 316.91},
#  'hourly': {'summary': 'Partly cloudy starting tomorrow afternoon, continuing until tomorrow evening.',
#   'icon': 'partly-cloudy-day',
#   'data': [{'time': 1527793200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.04,
#     'apparentTemperature': 59.04,
#     'dewPoint': 35.3,
#     'humidity': 0.41,
#     'pressure': 1024.21,
#     'windSpeed': 8.22,
#     'windGust': 8.85,
#     'windBearing': 142,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 6.22,
#     'ozone': 317.06},
#    {'time': 1527796800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.56,
#     'apparentTemperature': 54.56,
#     'dewPoint': 37.32,
#     'humidity': 0.52,
#     'pressure': 1024.2,
#     'windSpeed': 6.72,
#     'windGust': 7.2,
#     'windBearing': 143,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 6.22,
#     'ozone': 316.65},
#    {'time': 1527800400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 50.92,
#     'apparentTemperature': 50.92,
#     'dewPoint': 39.28,
#     'humidity': 0.64,
#     'pressure': 1024.14,
#     'windSpeed': 5.23,
#     'windGust': 5.95,
#     'windBearing': 145,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 6.22,
#     'ozone': 316.5},
#    {'time': 1527804000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 48.83,
#     'apparentTemperature': 47.18,
#     'dewPoint': 40.16,
#     'humidity': 0.72,
#     'pressure': 1024.03,
#     'windSpeed': 4.48,
#     'windGust': 5.49,
#     'windBearing': 149,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'visibility': 6.22,
#     'ozone': 316.59},
#    {'time': 1527807600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47.76,
#     'apparentTemperature': 46.02,
#     'dewPoint': 40.21,
#     'humidity': 0.75,
#     'pressure': 1023.87,
#     'windSpeed': 4.36,
#     'windGust': 5.41,
#     'windBearing': 156,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 316.96},
#    {'time': 1527811200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 47,
#     'apparentTemperature': 45.33,
#     'dewPoint': 40.38,
#     'humidity': 0.78,
#     'pressure': 1023.66,
#     'windSpeed': 4.1,
#     'windGust': 5.25,
#     'windBearing': 163,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 317.55},
#    {'time': 1527814800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 46.14,
#     'apparentTemperature': 44.79,
#     'dewPoint': 40.77,
#     'humidity': 0.81,
#     'pressure': 1023.36,
#     'windSpeed': 3.56,
#     'windGust': 4.63,
#     'windBearing': 168,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 318.36},
#    {'time': 1527818400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 45.71,
#     'apparentTemperature': 45.71,
#     'dewPoint': 41.28,
#     'humidity': 0.84,
#     'pressure': 1023,
#     'windSpeed': 2.88,
#     'windGust': 3.94,
#     'windBearing': 173,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 319.45},
#    {'time': 1527822000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 46.75,
#     'apparentTemperature': 46.75,
#     'dewPoint': 41.68,
#     'humidity': 0.82,
#     'pressure': 1022.65,
#     'windSpeed': 2.48,
#     'windGust': 3.77,
#     'windBearing': 179,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 320.76},
#    {'time': 1527825600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 50.18,
#     'apparentTemperature': 50.18,
#     'dewPoint': 41.99,
#     'humidity': 0.73,
#     'pressure': 1022.33,
#     'windSpeed': 2.55,
#     'windGust': 4.57,
#     'windBearing': 188,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 322.58},
#    {'time': 1527829200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.17,
#     'apparentTemperature': 55.17,
#     'dewPoint': 42.25,
#     'humidity': 0.62,
#     'pressure': 1022.03,
#     'windSpeed': 2.88,
#     'windGust': 5.91,
#     'windBearing': 197,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'ozone': 324.61},
#    {'time': 1527832800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 59.89,
#     'apparentTemperature': 59.89,
#     'dewPoint': 42.14,
#     'humidity': 0.52,
#     'pressure': 1021.67,
#     'windSpeed': 3.23,
#     'windGust': 6.88,
#     'windBearing': 203,
#     'cloudCover': 0,
#     'uvIndex': 1,
#     'ozone': 326.18},
#    {'time': 1527836400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 63.64,
#     'apparentTemperature': 63.64,
#     'dewPoint': 41.41,
#     'humidity': 0.44,
#     'pressure': 1021.28,
#     'windSpeed': 3.54,
#     'windGust': 7.08,
#     'windBearing': 206,
#     'cloudCover': 0,
#     'uvIndex': 2,
#     'ozone': 326.68},
#    {'time': 1527840000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.76,
#     'apparentTemperature': 66.76,
#     'dewPoint': 40.33,
#     'humidity': 0.38,
#     'pressure': 1020.85,
#     'windSpeed': 3.85,
#     'windGust': 6.93,
#     'windBearing': 206,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'ozone': 326.63},
#    {'time': 1527843600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 69.2,
#     'apparentTemperature': 69.2,
#     'dewPoint': 39.39,
#     'humidity': 0.34,
#     'pressure': 1020.4,
#     'windSpeed': 4.11,
#     'windGust': 6.93,
#     'windBearing': 206,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'ozone': 327},
#    {'time': 1527847200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.02,
#     'apparentTemperature': 71.02,
#     'dewPoint': 38.68,
#     'humidity': 0.31,
#     'pressure': 1019.94,
#     'windSpeed': 4.34,
#     'windGust': 7.26,
#     'windBearing': 206,
#     'cloudCover': 0.03,
#     'uvIndex': 5,
#     'ozone': 328.2},
#    {'time': 1527850800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 72.45,
#     'apparentTemperature': 72.45,
#     'dewPoint': 38.07,
#     'humidity': 0.29,
#     'pressure': 1019.43,
#     'windSpeed': 4.52,
#     'windGust': 7.74,
#     'windBearing': 205,
#     'cloudCover': 0.07,
#     'uvIndex': 5,
#     'ozone': 329.72},
#    {'time': 1527854400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 74.05,
#     'apparentTemperature': 74.05,
#     'dewPoint': 37.8,
#     'humidity': 0.27,
#     'pressure': 1018.87,
#     'windSpeed': 4.71,
#     'windGust': 8.29,
#     'windBearing': 206,
#     'cloudCover': 0.16,
#     'uvIndex': 4,
#     'ozone': 331.31},
#    {'time': 1527858000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.51,
#     'apparentTemperature': 75.51,
#     'dewPoint': 37.89,
#     'humidity': 0.26,
#     'pressure': 1018.18,
#     'windSpeed': 4.89,
#     'windGust': 8.85,
#     'windBearing': 208,
#     'cloudCover': 0.35,
#     'uvIndex': 3,
#     'ozone': 332.76},
#    {'time': 1527861600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.49,
#     'apparentTemperature': 76.49,
#     'dewPoint': 38.29,
#     'humidity': 0.25,
#     'pressure': 1017.45,
#     'windSpeed': 5.07,
#     'windGust': 9.47,
#     'windBearing': 213,
#     'cloudCover': 0.59,
#     'uvIndex': 2,
#     'ozone': 334.17},
#    {'time': 1527865200,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.47,
#     'apparentTemperature': 76.47,
#     'dewPoint': 39.03,
#     'humidity': 0.26,
#     'pressure': 1016.81,
#     'windSpeed': 5.23,
#     'windGust': 10.35,
#     'windBearing': 215,
#     'cloudCover': 0.72,
#     'uvIndex': 1,
#     'ozone': 335.74},
#    {'time': 1527868800,
#     'summary': 'Mostly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.38,
#     'apparentTemperature': 75.38,
#     'dewPoint': 40.24,
#     'humidity': 0.28,
#     'pressure': 1016.32,
#     'windSpeed': 5.32,
#     'windGust': 11.68,
#     'windBearing': 216,
#     'cloudCover': 0.67,
#     'uvIndex': 1,
#     'ozone': 337.76},
#    {'time': 1527872400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.25,
#     'apparentTemperature': 73.25,
#     'dewPoint': 41.82,
#     'humidity': 0.32,
#     'pressure': 1015.95,
#     'windSpeed': 5.4,
#     'windGust': 13.25,
#     'windBearing': 215,
#     'cloudCover': 0.52,
#     'uvIndex': 0,
#     'ozone': 339.82},
#    {'time': 1527876000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.38,
#     'apparentTemperature': 70.38,
#     'dewPoint': 43.28,
#     'humidity': 0.38,
#     'pressure': 1015.67,
#     'windSpeed': 5.56,
#     'windGust': 14.62,
#     'windBearing': 215,
#     'cloudCover': 0.36,
#     'uvIndex': 0,
#     'ozone': 341.22},
#    {'time': 1527879600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 66.42,
#     'apparentTemperature': 66.42,
#     'dewPoint': 44.56,
#     'humidity': 0.45,
#     'pressure': 1015.46,
#     'windSpeed': 6.04,
#     'windGust': 15.76,
#     'windBearing': 212,
#     'cloudCover': 0.23,
#     'uvIndex': 0,
#     'ozone': 341.45},
#    {'time': 1527883200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.15,
#     'apparentTemperature': 62.15,
#     'dewPoint': 45.77,
#     'humidity': 0.55,
#     'pressure': 1015.36,
#     'windSpeed': 6.6,
#     'windGust': 16.71,
#     'windBearing': 209,
#     'cloudCover': 0.09,
#     'uvIndex': 0,
#     'ozone': 340.91},
#    {'time': 1527886800,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 58.77,
#     'apparentTemperature': 58.77,
#     'dewPoint': 46.76,
#     'humidity': 0.64,
#     'pressure': 1015.26,
#     'windSpeed': 6.75,
#     'windGust': 17,
#     'windBearing': 208,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 339.96},
#    {'time': 1527890400,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 56.81,
#     'apparentTemperature': 56.81,
#     'dewPoint': 47.55,
#     'humidity': 0.71,
#     'pressure': 1015.17,
#     'windSpeed': 6.31,
#     'windGust': 16.36,
#     'windBearing': 222,
#     'cloudCover': 0,
#     'uvIndex': 0,
#     'ozone': 338.39},
#    {'time': 1527894000,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 55.73,
#     'apparentTemperature': 55.73,
#     'dewPoint': 48.13,
#     'humidity': 0.76,
#     'pressure': 1015.09,
#     'windSpeed': 5.54,
#     'windGust': 15.09,
#     'windBearing': 239,
#     'cloudCover': 0.01,
#     'uvIndex': 0,
#     'ozone': 336.57},
#    {'time': 1527897600,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.87,
#     'apparentTemperature': 54.87,
#     'dewPoint': 48.42,
#     'humidity': 0.79,
#     'pressure': 1014.99,
#     'windSpeed': 4.85,
#     'windGust': 13.51,
#     'windBearing': 222,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'ozone': 335.33},
#    {'time': 1527901200,
#     'summary': 'Clear',
#     'icon': 'clear-night',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 53.9,
#     'apparentTemperature': 53.9,
#     'dewPoint': 48.26,
#     'humidity': 0.81,
#     'pressure': 1014.81,
#     'windSpeed': 4.27,
#     'windGust': 11.3,
#     'windBearing': 134,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'ozone': 335.36},
#    {'time': 1527904800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 53.33,
#     'apparentTemperature': 53.33,
#     'dewPoint': 47.84,
#     'humidity': 0.82,
#     'pressure': 1014.62,
#     'windSpeed': 3.73,
#     'windGust': 8.77,
#     'windBearing': 13,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'ozone': 336.1},
#    {'time': 1527908400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 54.31,
#     'apparentTemperature': 54.31,
#     'dewPoint': 47.44,
#     'humidity': 0.78,
#     'pressure': 1014.49,
#     'windSpeed': 3.45,
#     'windGust': 7.31,
#     'windBearing': 292,
#     'cloudCover': 0.03,
#     'uvIndex': 0,
#     'ozone': 337.01},
#    {'time': 1527912000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 57.75,
#     'apparentTemperature': 57.75,
#     'dewPoint': 47.2,
#     'humidity': 0.68,
#     'pressure': 1014.45,
#     'windSpeed': 3.72,
#     'windGust': 7.95,
#     'windBearing': 293,
#     'cloudCover': 0.02,
#     'uvIndex': 0,
#     'ozone': 337.9},
#    {'time': 1527915600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 62.75,
#     'apparentTemperature': 62.75,
#     'dewPoint': 47.01,
#     'humidity': 0.56,
#     'pressure': 1014.47,
#     'windSpeed': 4.3,
#     'windGust': 9.64,
#     'windBearing': 334,
#     'cloudCover': 0.02,
#     'uvIndex': 1,
#     'ozone': 339.11},
#    {'time': 1527919200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 67.26,
#     'apparentTemperature': 67.26,
#     'dewPoint': 46.94,
#     'humidity': 0.48,
#     'pressure': 1014.48,
#     'windSpeed': 4.58,
#     'windGust': 10.53,
#     'windBearing': 7,
#     'cloudCover': 0.01,
#     'uvIndex': 1,
#     'ozone': 340.29},
#    {'time': 1527922800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 70.83,
#     'apparentTemperature': 70.83,
#     'dewPoint': 47.18,
#     'humidity': 0.43,
#     'pressure': 1014.52,
#     'windSpeed': 4.23,
#     'windGust': 9.47,
#     'windBearing': 13,
#     'cloudCover': 0.01,
#     'uvIndex': 2,
#     'ozone': 341.39},
#    {'time': 1527926400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.9,
#     'apparentTemperature': 73.9,
#     'dewPoint': 47.56,
#     'humidity': 0.39,
#     'pressure': 1014.57,
#     'windSpeed': 3.55,
#     'windGust': 7.62,
#     'windBearing': 10,
#     'cloudCover': 0,
#     'uvIndex': 3,
#     'ozone': 342.48},
#    {'time': 1527930000,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 76.19,
#     'apparentTemperature': 76.19,
#     'dewPoint': 47.74,
#     'humidity': 0.37,
#     'pressure': 1014.53,
#     'windSpeed': 2.98,
#     'windGust': 6.46,
#     'windBearing': 11,
#     'cloudCover': 0,
#     'uvIndex': 4,
#     'ozone': 343.62},
#    {'time': 1527933600,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.99,
#     'apparentTemperature': 77.99,
#     'dewPoint': 47.47,
#     'humidity': 0.34,
#     'pressure': 1014.37,
#     'windSpeed': 2.58,
#     'windGust': 6.72,
#     'windBearing': 18,
#     'cloudCover': 0,
#     'uvIndex': 5,
#     'ozone': 345.22},
#    {'time': 1527937200,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.18,
#     'apparentTemperature': 79.18,
#     'dewPoint': 46.97,
#     'humidity': 0.32,
#     'pressure': 1014.13,
#     'windSpeed': 1.57,
#     'windGust': 7.69,
#     'windBearing': 294,
#     'cloudCover': 0,
#     'uvIndex': 5,
#     'ozone': 346.92},
#    {'time': 1527940800,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.84,
#     'apparentTemperature': 79.84,
#     'dewPoint': 46.46,
#     'humidity': 0.31,
#     'pressure': 1013.9,
#     'windSpeed': 1.94,
#     'windGust': 8.66,
#     'windBearing': 300,
#     'cloudCover': 0,
#     'uvIndex': 5,
#     'ozone': 347.49},
#    {'time': 1527944400,
#     'summary': 'Clear',
#     'icon': 'clear-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 79.59,
#     'apparentTemperature': 79.59,
#     'dewPoint': 45.94,
#     'humidity': 0.31,
#     'pressure': 1013.63,
#     'windSpeed': 1.97,
#     'windGust': 9.32,
#     'windBearing': 310,
#     'cloudCover': 0.11,
#     'uvIndex': 3,
#     'ozone': 346.05},
#    {'time': 1527948000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 78.59,
#     'apparentTemperature': 78.59,
#     'dewPoint': 45.41,
#     'humidity': 0.31,
#     'pressure': 1013.36,
#     'windSpeed': 0.86,
#     'windGust': 9.97,
#     'windBearing': 313,
#     'cloudCover': 0.25,
#     'uvIndex': 2,
#     'ozone': 343.53},
#    {'time': 1527951600,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 77.18,
#     'apparentTemperature': 77.18,
#     'dewPoint': 45.16,
#     'humidity': 0.32,
#     'pressure': 1013.12,
#     'windSpeed': 3.31,
#     'windGust': 10.93,
#     'windBearing': 213,
#     'cloudCover': 0.36,
#     'uvIndex': 1,
#     'ozone': 341.38},
#    {'time': 1527955200,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 75.74,
#     'apparentTemperature': 75.74,
#     'dewPoint': 45.33,
#     'humidity': 0.34,
#     'pressure': 1012.86,
#     'windSpeed': 3.59,
#     'windGust': 12.55,
#     'windBearing': 214,
#     'cloudCover': 0.38,
#     'uvIndex': 1,
#     'ozone': 340.26},
#    {'time': 1527958800,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 73.76,
#     'apparentTemperature': 73.76,
#     'dewPoint': 45.77,
#     'humidity': 0.37,
#     'pressure': 1012.63,
#     'windSpeed': 3.76,
#     'windGust': 14.48,
#     'windBearing': 216,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'ozone': 339.52},
#    {'time': 1527962400,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0,
#     'precipProbability': 0,
#     'temperature': 71.23,
#     'apparentTemperature': 71.23,
#     'dewPoint': 46.31,
#     'humidity': 0.41,
#     'pressure': 1012.53,
#     'windSpeed': 3.76,
#     'windGust': 15.9,
#     'windBearing': 225,
#     'cloudCover': 0.37,
#     'uvIndex': 0,
#     'ozone': 338.61},
#    {'time': 1527966000,
#     'summary': 'Partly Cloudy',
#     'icon': 'partly-cloudy-day',
#     'precipIntensity': 0.0002,
#     'precipProbability': 0.03,
#     'precipType': 'rain',
#     'temperature': 67.85,
#     'apparentTemperature': 67.85,
#     'dewPoint': 46.92,
#     'humidity': 0.47,
#     'pressure': 1012.64,
#     'windSpeed': 3.36,
#     'windGust': 16.59,
#     'windBearing': 251,
#     'cloudCover': 0.39,
#     'uvIndex': 0,
#     'ozone': 337.22}]},
#  'daily': {'summary': 'No precipitation throughout the week, with high temperatures peaking at 80°F on Saturday.',
#   'icon': 'clear-day',
#   'data': [{'time': 1527717600,
#     'summary': 'Partly cloudy in the morning.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1527731162,
#     'sunsetTime': 1527796071,
#     'moonPhase': 0.56,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1527760800,
#     'precipProbability': 0,
#     'temperatureHigh': 68.34,
#     'temperatureHighTime': 1527771600,
#     'temperatureLow': 45.71,
#     'temperatureLowTime': 1527818400,
#     'apparentTemperatureHigh': 68.34,
#     'apparentTemperatureHighTime': 1527771600,
#     'apparentTemperatureLow': 44.79,
#     'apparentTemperatureLowTime': 1527814800,
#     'dewPoint': 40.29,
#     'humidity': 0.5,
#     'pressure': 1025.5,
#     'windSpeed': 5.66,
#     'windGust': 16.62,
#     'windGustTime': 1527735600,
#     'windBearing': 76,
#     'cloudCover': 0.09,
#     'uvIndex': 5,
#     'uvIndexTime': 1527760800,
#     'visibility': 6.22,
#     'ozone': 316.63,
#     'temperatureMin': 49.47,
#     'temperatureMinTime': 1527728400,
#     'temperatureMax': 68.34,
#     'temperatureMaxTime': 1527771600,
#     'apparentTemperatureMin': 47.51,
#     'apparentTemperatureMinTime': 1527728400,
#     'apparentTemperatureMax': 68.34,
#     'apparentTemperatureMaxTime': 1527771600},
#    {'time': 1527804000,
#     'summary': 'Partly cloudy starting in the afternoon, continuing until evening.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1527817478,
#     'sunsetTime': 1527882573,
#     'moonPhase': 0.59,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1527804000,
#     'precipProbability': 0,
#     'temperatureHigh': 76.49,
#     'temperatureHighTime': 1527861600,
#     'temperatureLow': 53.33,
#     'temperatureLowTime': 1527904800,
#     'apparentTemperatureHigh': 76.49,
#     'apparentTemperatureHighTime': 1527861600,
#     'apparentTemperatureLow': 53.33,
#     'apparentTemperatureLowTime': 1527904800,
#     'dewPoint': 41.01,
#     'humidity': 0.5,
#     'pressure': 1019.74,
#     'windSpeed': 4.18,
#     'windGust': 17,
#     'windGustTime': 1527886800,
#     'windBearing': 200,
#     'cloudCover': 0.16,
#     'uvIndex': 5,
#     'uvIndexTime': 1527847200,
#     'ozone': 329.01,
#     'temperatureMin': 45.71,
#     'temperatureMinTime': 1527818400,
#     'temperatureMax': 76.49,
#     'temperatureMaxTime': 1527861600,
#     'apparentTemperatureMin': 44.79,
#     'apparentTemperatureMinTime': 1527814800,
#     'apparentTemperatureMax': 76.49,
#     'apparentTemperatureMaxTime': 1527861600},
#    {'time': 1527890400,
#     'summary': 'Partly cloudy starting in the afternoon.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1527903798,
#     'sunsetTime': 1527969072,
#     'moonPhase': 0.62,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1527973200,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperatureHigh': 79.84,
#     'temperatureHighTime': 1527940800,
#     'temperatureLow': 54.23,
#     'temperatureLowTime': 1527991200,
#     'apparentTemperatureHigh': 79.84,
#     'apparentTemperatureHighTime': 1527940800,
#     'apparentTemperatureLow': 54.23,
#     'apparentTemperatureLowTime': 1527991200,
#     'dewPoint': 47.04,
#     'humidity': 0.51,
#     'pressure': 1013.97,
#     'windSpeed': 1.18,
#     'windGust': 16.77,
#     'windGustTime': 1527969600,
#     'windBearing': 261,
#     'cloudCover': 0.14,
#     'uvIndex': 5,
#     'uvIndexTime': 1527933600,
#     'ozone': 339.98,
#     'temperatureMin': 53.33,
#     'temperatureMinTime': 1527904800,
#     'temperatureMax': 79.84,
#     'temperatureMaxTime': 1527940800,
#     'apparentTemperatureMin': 53.33,
#     'apparentTemperatureMinTime': 1527904800,
#     'apparentTemperatureMax': 79.84,
#     'apparentTemperatureMaxTime': 1527940800},
#    {'time': 1527976800,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1527990121,
#     'sunsetTime': 1528055567,
#     'moonPhase': 0.65,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0004,
#     'precipIntensityMaxTime': 1527994800,
#     'precipProbability': 0.05,
#     'precipType': 'rain',
#     'temperatureHigh': 76.44,
#     'temperatureHighTime': 1528038000,
#     'temperatureLow': 59.84,
#     'temperatureLowTime': 1528088400,
#     'apparentTemperatureHigh': 76.44,
#     'apparentTemperatureHighTime': 1528038000,
#     'apparentTemperatureLow': 59.84,
#     'apparentTemperatureLowTime': 1528088400,
#     'dewPoint': 46.06,
#     'humidity': 0.51,
#     'pressure': 1012.33,
#     'windSpeed': 2.1,
#     'windGust': 19.99,
#     'windGustTime': 1528059600,
#     'windBearing': 174,
#     'cloudCover': 0.49,
#     'uvIndex': 3,
#     'uvIndexTime': 1528016400,
#     'ozone': 319.18,
#     'temperatureMin': 54.23,
#     'temperatureMinTime': 1527991200,
#     'temperatureMax': 76.44,
#     'temperatureMaxTime': 1528038000,
#     'apparentTemperatureMin': 54.23,
#     'apparentTemperatureMinTime': 1527991200,
#     'apparentTemperatureMax': 76.44,
#     'apparentTemperatureMaxTime': 1528038000},
#    {'time': 1528063200,
#     'summary': 'Partly cloudy until afternoon.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1528076449,
#     'sunsetTime': 1528142059,
#     'moonPhase': 0.68,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0003,
#     'precipIntensityMaxTime': 1528102800,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 71,
#     'temperatureHighTime': 1528117200,
#     'temperatureLow': 47.43,
#     'temperatureLowTime': 1528167600,
#     'apparentTemperatureHigh': 71,
#     'apparentTemperatureHighTime': 1528117200,
#     'apparentTemperatureLow': 42.44,
#     'apparentTemperatureLowTime': 1528167600,
#     'dewPoint': 39.64,
#     'humidity': 0.43,
#     'pressure': 1007.73,
#     'windSpeed': 4.3,
#     'windGust': 24.79,
#     'windGustTime': 1528092000,
#     'windBearing': 357,
#     'cloudCover': 0.39,
#     'uvIndex': 4,
#     'uvIndexTime': 1528110000,
#     'ozone': 318.38,
#     'temperatureMin': 54.13,
#     'temperatureMinTime': 1528146000,
#     'temperatureMax': 71,
#     'temperatureMaxTime': 1528117200,
#     'apparentTemperatureMin': 54.13,
#     'apparentTemperatureMinTime': 1528146000,
#     'apparentTemperatureMax': 71,
#     'apparentTemperatureMaxTime': 1528117200},
#    {'time': 1528149600,
#     'summary': 'Mostly cloudy starting in the afternoon, continuing until evening.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1528162781,
#     'sunsetTime': 1528228548,
#     'moonPhase': 0.71,
#     'precipIntensity': 0.0001,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1528149600,
#     'precipProbability': 0.04,
#     'precipType': 'rain',
#     'temperatureHigh': 62.08,
#     'temperatureHighTime': 1528207200,
#     'temperatureLow': 46.69,
#     'temperatureLowTime': 1528243200,
#     'apparentTemperatureHigh': 62.08,
#     'apparentTemperatureHighTime': 1528207200,
#     'apparentTemperatureLow': 43.84,
#     'apparentTemperatureLowTime': 1528243200,
#     'dewPoint': 28.33,
#     'humidity': 0.39,
#     'pressure': 1014.45,
#     'windSpeed': 7.98,
#     'windGust': 27.03,
#     'windGustTime': 1528160400,
#     'windBearing': 350,
#     'cloudCover': 0.28,
#     'uvIndex': 5,
#     'uvIndexTime': 1528192800,
#     'ozone': 337.49,
#     'temperatureMin': 47.43,
#     'temperatureMinTime': 1528167600,
#     'temperatureMax': 62.08,
#     'temperatureMaxTime': 1528207200,
#     'apparentTemperatureMin': 42.44,
#     'apparentTemperatureMinTime': 1528167600,
#     'apparentTemperatureMax': 62.08,
#     'apparentTemperatureMaxTime': 1528207200},
#    {'time': 1528236000,
#     'summary': 'Mostly cloudy throughout the day.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1528249117,
#     'sunsetTime': 1528315032,
#     'moonPhase': 0.74,
#     'precipIntensity': 0.0005,
#     'precipIntensityMax': 0.002,
#     'precipIntensityMaxTime': 1528286400,
#     'precipProbability': 0.1,
#     'precipType': 'rain',
#     'temperatureHigh': 64.68,
#     'temperatureHighTime': 1528286400,
#     'temperatureLow': 45.77,
#     'temperatureLowTime': 1528336800,
#     'apparentTemperatureHigh': 64.68,
#     'apparentTemperatureHighTime': 1528286400,
#     'apparentTemperatureLow': 42.48,
#     'apparentTemperatureLowTime': 1528336800,
#     'dewPoint': 33.48,
#     'humidity': 0.46,
#     'pressure': 1018.34,
#     'windSpeed': 2.95,
#     'windGust': 17.61,
#     'windGustTime': 1528246800,
#     'windBearing': 345,
#     'cloudCover': 0.73,
#     'uvIndex': 3,
#     'uvIndexTime': 1528279200,
#     'ozone': 340.61,
#     'temperatureMin': 46.69,
#     'temperatureMinTime': 1528243200,
#     'temperatureMax': 64.68,
#     'temperatureMaxTime': 1528286400,
#     'apparentTemperatureMin': 43.84,
#     'apparentTemperatureMinTime': 1528243200,
#     'apparentTemperatureMax': 64.68,
#     'apparentTemperatureMaxTime': 1528286400},
#    {'time': 1528322400,
#     'summary': 'Mostly cloudy starting in the afternoon.',
#     'icon': 'partly-cloudy-day',
#     'sunriseTime': 1528335458,
#     'sunsetTime': 1528401513,
#     'moonPhase': 0.77,
#     'precipIntensity': 0,
#     'precipIntensityMax': 0.0002,
#     'precipIntensityMaxTime': 1528372800,
#     'precipProbability': 0,
#     'temperatureHigh': 67.99,
#     'temperatureHighTime': 1528380000,
#     'temperatureLow': 47.13,
#     'temperatureLowTime': 1528423200,
#     'apparentTemperatureHigh': 67.99,
#     'apparentTemperatureHighTime': 1528380000,
#     'apparentTemperatureLow': 45.69,
#     'apparentTemperatureLowTime': 1528419600,
#     'dewPoint': 32.28,
#     'humidity': 0.4,
#     'pressure': 1021.5,
#     'windSpeed': 2.44,
#     'windGust': 26.33,
#     'windGustTime': 1528401600,
#     'windBearing': 208,
#     'cloudCover': 0.34,
#     'uvIndex': 5,
#     'uvIndexTime': 1528365600,
#     'ozone': 348.07,
#     'temperatureMin': 45.77,
#     'temperatureMinTime': 1528336800,
#     'temperatureMax': 67.99,
#     'temperatureMaxTime': 1528380000,
#     'apparentTemperatureMin': 42.48,
#     'apparentTemperatureMinTime': 1528336800,
#     'apparentTemperatureMax': 67.99,
#     'apparentTemperatureMaxTime': 1528380000}]},
#  'flags': {'sources': ['isd', 'cmc', 'gfs', 'madis'],
#   'isd-stations': ['020770-99999',
#    '024430-99999',
#    '024600-99999',
#    '024620-99999',
#    '024640-99999',
#    '024650-99999',
#    '024690-99999',
#    '024830-99999',
#    '024840-99999',
#    '024850-99999',
#    '024860-99999',
#    '024870-99999',
#    '024890-99999',
#    '024900-99999',
#    '024990-99999',
#    '025800-99999'],
#   'units': 'us'},
#  'offset': 2}

# %% [markdown]
# ## 2) What's the current wind speed? How much warmer does it feel than it actually is?
#
# - *Tip: You can do this by browsing through the dictionaries, but it might be easier to read the documentation*
# - *Tip: For the second half: it **is** one temperature, and it **feels** a different temperature. Calculate the difference.*

# %%
print("The current wind speed in MPH is", data['currently']['windSpeed'])
# Out:
# The current wind speed in MPH is 7.66

# %%
if float(data['currently']['apparentTemperature']) == float(data['currently']['temperature']):
    print("The apparent temperature and the actual temperature are the same:", data['currently']['temperature'])
elif float(data['currently']['apparentTemperature']) > float(data['currently']['temperature']):
    print("It feels", (float(data['currently']['apparentTemperature'])-float(data['currently']['temperature'])), "degrees warmer.")
else:
    print("It feels", (float(data['currently']['temperature'])-float(data['currently']['apparentTemperature'])), "degrees colder.")
# Out:
# The apparent temperature and the actual temperature are the same: 57.39

# %%
#Not the neatest, but it does the job.

# %% [markdown]
# ## 3) Today's forecast is the FIRST daily forecast. For the place you decided on above, how much of the moon is currently visible?
#
# - *Tip: This does **not** use the `currently` key.*
# - *Tip: It might be helpful to save the forecast into its own variable*

# %%
moon_visible = ""

# %%
moon_visible = data['daily']['data'][0]['moonPhase']

# %%
print("The moon is nearly full (waning gibbous), with a lunation number of", moon_visible)
# Out:
# The moon is nearly full (waning gibbous), with a lunation number of 0.56

# %% [markdown]
# ## 4) What's the difference between the high and low temperatures for today?

# %%
high = float(data['daily']['data'][0]['temperatureHigh'])

# %%
low = float(data['daily']['data'][0]['temperatureLow'])

# %%
difference_high_low = abs(high-low)
print("The difference between today's high and low temperatures in Stockholm were", round(difference_high_low), "degrees")
# Out:
# The difference between today's high and low temperatures in Stockholm were 23 degrees

# %% [markdown]
# ## 5) Go through the daily forecasts, printing out the next week's worth of predictions.
#
# I'd like to know the **high temperature** for each day, and whether it's **hot, warm, or cold** (based on what temperatures you think are hot, warm or cold).
#
# - *Tip: Is it returning F or C? You can change them by adding `?units=us` or `?units=si` onto the end of the URL.*
# - *Tip: You'll need to use an `if` statement to say whether it is hot, warm or cold.*

# %%
# I still don't understand the imperial system, so let's make a new call with scientific units.

data_si = requests.get('https://api.darksky.net/forecast/4a49a43f92c8ce2a327f67aa2f020d79/59.334591,18.063240?units=si').json()

for day in data_si['daily']['data']:
    print(day['summary'], "High temperature of", day['temperatureHigh'], "degrees Celsius.")
# Out:
# Partly cloudy in the morning. High temperature of 20.19 degrees Celsius.
# Partly cloudy starting in the afternoon, continuing until evening. High temperature of 24.72 degrees Celsius.
# Partly cloudy starting in the afternoon. High temperature of 26.58 degrees Celsius.
# Mostly cloudy throughout the day. High temperature of 24.69 degrees Celsius.
# Partly cloudy until afternoon. High temperature of 21.67 degrees Celsius.
# Mostly cloudy starting in the afternoon, continuing until evening. High temperature of 17.24 degrees Celsius.
# Mostly cloudy throughout the day. High temperature of 20.74 degrees Celsius.
# Mostly cloudy starting in the afternoon. High temperature of 19.99 degrees Celsius.

# %% [markdown]
# # 6) What will be the hottest day in the next week? What is the high temperature on that day?
#
# It's okay if your result looks like `1453363200`. If you want to be extra-fancy, though, format it as a **real date** - the weird number is called a **UNIX timestamp**, which might help in googling.
#
# - *Tip: It's okay to skip this if it seems too difficult!*

# %%
hottest_day = 0
hottest_day_time = ""

# %%
for day in data_si['daily']['data']:
    if float(day['temperatureHigh']) > hottest_day:
        hottest_day = float(day['temperatureHigh'])
        hottest_day_time = day['time']

# %%
hottest_day_time
# Out:
# 1527890400

# %%
import datetime
print(datetime.datetime.utcfromtimestamp(hottest_day_time))
# Out:
# 2018-06-01 22:00:00

# %% [markdown]
# ## 7) What's the weather looking like for the next 24+ hours in Miami, Florida?
#
# I'd like to know the temperature for every hour, and if it's going to have cloud cover of more than 50% say "{temperature} and cloudy" instead of just the temperature.
#
#
# - *Tip: Be sure to remember how latitude and longitude are done with positive and negative numbers*
# - *Tip: How do you represent "50%" for cloud cover?*

# %%
miami = requests.get('https://api.darksky.net/forecast/4a49a43f92c8ce2a327f67aa2f020d79/25.761681,-80.191788?units=si').json()
#NB: I considered adding the request parameter extend=hourly in the above url, but it's not necessary as the regular 
#request yields 48 hours worth of results.

# %%
len(miami['hourly']['data']) #Just to confirm that we have enough hourly data.
# Out:
# 49

# %%
for hour in miami['hourly']['data']:
    if float(hour['cloudCover']) > 0.5: #cloudCover is defined as percentage of sky occluded by clouds
        print(hour['temperature'],"and cloudy")
    else:
        print(hour['temperature'])
# Out:
# 29.03
# 28.99 and cloudy
# 28.73 and cloudy
# 28.33 and cloudy
# 27.88 and cloudy
# 27.35 and cloudy
# 26.92 and cloudy
# 26.61 and cloudy
# 26.27 and cloudy
# 25.9 and cloudy
# 25.44 and cloudy
# 25.39 and cloudy
# 25.46 and cloudy
# 25.73 and cloudy
# 25.92 and cloudy
# 26.36 and cloudy
# 26.8 and cloudy
# 27.34 and cloudy
# 27.96 and cloudy
# 28.47 and cloudy
# 28.76 and cloudy
# 28.86 and cloudy
# 29.05 and cloudy
# 29.35 and cloudy
# 29.53 and cloudy
# 29.52
# 29.19
# 28.69
# 28.21
# 27.62 and cloudy
# 27.06 and cloudy
# 26.55 and cloudy
# 26.18 and cloudy
# 25.84 and cloudy
# 25.5 and cloudy
# 25.12 and cloudy
# 24.91 and cloudy
# 24.91 and cloudy
# 25.11 and cloudy
# 25.42 and cloudy
# 25.91 and cloudy
# 26.75 and cloudy
# 27.79 and cloudy
# 28.76 and cloudy
# 29.41 and cloudy
# 29.99 and cloudy
# 30.39 and cloudy
# 30.6 and cloudy
# 30.51

# %% [markdown]
# # 8) For the next 24-ish hours in Miami, what percent of the time is the temperature above 85 degrees?
#
# If they give you 48 hours instead of 24, that's okay.
#
# - *Tip: You might want to read up on [looping patterns](http://jonathansoma.com/lede/foundations-2017/classes/data%20structures/looping-patterns/)*

# %%
#Well shoot. I'm assuming that 85 is in farenheit. Time to reping the API! I'll exlcude some of the unnecessary stuff.
miami = requests.get('https://api.darksky.net/forecast/4a49a43f92c8ce2a327f67aa2f020d79/25.761681,-80.191788?exclude=currently,minutely,daily,alerts,flags').json()

# %%
#Gonna go with 48 hours, getting the variables ready below.
hours_above_85 = 0
total_hours =len(miami['hourly']['data'])
total_hours
# Out:
# 49

# %%
#Let's jump into a loop!

for hour in miami['hourly']['data']:
    if float(hour['temperature']) > 85:
        hours_above_85 += 1 #remeber, we are only counting the numbers of hours above 85 degrees.

print(round(100*hours_above_85/total_hours),"% of the hours in the next 48 hours in Miami will be above 85 degrees.")
#I noticed that if I rerun just this cell, the percentage increases. I believe this is because I put the hours
#above 85 variable in a separate cell, so it does not reset to 0. Good lesson.
# Out:
# 12 % of the hours in the next 48 hours in Miami will be above 85 degrees.

# %% [markdown]
# ## 9) What was the temperature in Central Park on Christmas Day, 2012? How about 2007? 2005? How far back does the API allow you to go?
#
# - *Tip: You'll need to use UNIX time, which is the number of seconds since January 1, 1970. Google can help you convert a normal date!*
# - *Tip: You'll want to use Forecast.io's "time machine" API, [documentation here](https://darksky.net/dev/docs/time-machine)*

# %%
# First, let's get some UNIX time stamps:
xmass_2012 = datetime.datetime(2012, 12, 25, 15, 0, 1).strftime("%s")

xmass_2012
# Out:
# '1356465601'

# %%
response = requests.get('https://api.darksky.net/forecast/4a49a43f92c8ce2a327f67aa2f020d79/40.785091,-73.968285,{}?exclude=currently,flags,hourly'.format('1356465601'))

# %%
data = response.json()

# %%
data['daily']['data'][0]['temperatureHigh']
# Out:
# 40.71

# %%
#But it's a lot of work to do all that manually. I'm going to attempt to define a function to do this for me.

def temp_at_xmass(year):
    xmass_unix = datetime.datetime(year,12,12,12,0,0).strftime('%s')
    url = 'https://api.darksky.net/forecast/4a49a43f92c8ce2a327f67aa2f020d79/40.785091,-73.968285,{}?exclude=currently,flags,hourly'.format(xmass_unix)
    #print(xmass_unix)
    #print(url)
    data = requests.get(url).json()
    return data['daily']['data'][0]['temperatureHigh']

# %%
print(temp_at_xmass(2012))
print(temp_at_xmass(2007))
temp_at_xmass(2005)
# Out:
# 43.27
# 52.01
# 37.04

# %%
# it works! Elation. Now let's see if we can break the API.
for year in range(2018, 1936, -1):
    print(temp_at_xmass(year))
# Out:
# 42.48
# 49.82
# 45.24
# 64.53
# 37.2
# 27.24
# 43.27
# 43.53
# 55.98
# 43.85
# 43.4
# 52.01
# 51.98
# 37.04
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-166-4bc60574e3a5> in <module>()
#       1 # it works! Elation. Now let's see if we can break the API.
#       2 for year in range(2018, 1936, -1):
# ----> 3     print(temp_at_xmass(year))
#
# <ipython-input-146-d5d7ef211ea9> in temp_at_xmass(year)
#       6     #print(xmass_unix)
#       7     #print(url)
# ----> 8     data = requests.get(url).json()
#       9     return data['daily']['data'][0]['temperatureHigh']
#      10
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/.pyenv/versions/3.6.4/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
#And I've been kicked out. But I think the earliest year is around 1936.

# %%
import pandas as pd

# %%
df = pd.read_csv('ancestry/ACS_16_5YR_B04006.csv', encoding = "ISO-8859-1" )

# %%
df.head()
# Out:
#            GEO.id  GEO.id2        GEO.display-label  HD01_VD01  HD01_VD02  \
# 0  0500000US01001     1001  Autauga County, Alabama      55049          0
# 1  0500000US01003     1003  Baldwin County, Alabama     199510          0
# 2  0500000US01005     1005  Barbour County, Alabama      26614          0
# 3  0500000US01007     1007     Bibb County, Alabama      22572          0
# 4  0500000US01009     1009   Blount County, Alabama      57704          0
#
#    HD01_VD03  HD01_VD04  HD01_VD05  HD01_VD06  HD01_VD07     ...      \
# 0          0          0       8930         26          0     ...
# 1          0          0      49852        439          0     ...
# 2          0          0       4649          5          0     ...
# 3          0          0       2841          0          0     ...
# 4          0          0       8169        133          0     ...
#
#    HD01_VD100  HD01_VD101  HD01_VD102  HD01_VD103  HD01_VD104  HD01_VD105  \
# ...

# %%
df['county'] = df['GEO.display-label'].str.extract(r"^(.*) County")

# %%
df['percentage_swedes'] = 100*df.HD01_VD89/df.HD01_VD01

# %%
df.to_csv('ancestry/ACS_16_5YR_B04006.csv', index=False)
